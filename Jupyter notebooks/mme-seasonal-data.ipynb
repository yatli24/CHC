# %%
# import necessary libraries
import pandas as pd
import numpy as np
import glob
import os

# %%
# Initialize an empty dictionary to store DataFrames
dfs_dict = {}

# initiate file list
list_of_files = glob.glob('data/csv/*')

files_path = []

for path in list_of_files:
    path_mod = path.replace('\\', '/')
    files_path.append(path_mod)

for f in files_path:
    df = pd.read_csv(f)
    df['region'] = '_'.join(f.split('/')[-1].split('_')[0:-3])
    dfs_dict[f] = df

mme_df = pd.concat(dfs_dict.values()).groupby(['season', 'date_of_prediction', 'region', 'realization_year'])[['predicted_precip','precip']].mean().reset_index()
mme_df['model'] = 'MME'
mme_df
# Out:
#      season date_of_prediction               region  realization_year  \
# 0       AMJ         1992-10-01      eastern_ukraine              1993
# 1       AMJ         1992-11-01      eastern_ukraine              1993
# 2       AMJ         1992-12-01      eastern_ukraine              1993
# 3       AMJ         1993-01-01      eastern_ukraine              1993
# 4       AMJ         1993-02-01      eastern_ukraine              1993
# ...     ...                ...                  ...               ...
# 4027    SON         2024-05-01  lake_victoria_basin              2024
# 4028    SON         2024-06-01  lake_victoria_basin              2024
# 4029    SON         2024-07-01  lake_victoria_basin              2024
# 4030    SON         2024-08-01  lake_victoria_basin              2024
# 4031    SON         2024-09-01  lake_victoria_basin              2024
#
#       predicted_precip      precip model
# 0             1.456996   54.292755   MME
# 1             1.544989   52.405428   MME
# 2             1.591193   53.797535   MME
# 3             1.593886   54.292755   MME
# 4             1.613829   54.292755   MME
# ...                ...         ...   ...
# 4027          5.722701  109.986840   MME
# 4028          6.138367  128.403060   MME
# 4029          5.502887  128.403060   MME
# 4030          5.725439  128.403060   MME
# 4031          5.462045  128.403060   MME
#
# [4032 rows x 7 columns]

# %%
grouped = mme_df.groupby('region')

for region, region_df in grouped:
    region_name = str(region)
    model = 'MME'
    filename = f'data/csv/seasonal/seasonal_average/{region_name}_{model}_merged_seasonal.csv'
    region_df.to_csv(filename)
